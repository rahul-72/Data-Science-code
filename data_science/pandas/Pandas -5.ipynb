# %%
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns 
import pandas as pd

# %matplotlib inline

plt.style.use('seaborn')

# %%
x = np.random.randint(20,50,10)

# %%
x
# Out:
# array([31, 32, 32, 36, 36, 29, 42, 35, 38, 34])

# %%
x_bar = x.mean()
x_1 = [ 0,10]
y_1 = [ x_bar,x_bar]
x_dev  = abs(x - x_bar)
print(x_dev)
print(x_dev.sum()/len(x))

sns.scatterplot(np.arange(x.size),x)
sns.lineplot(x_1,y_1,c='r')
plt.show()
# Out:
# [3.5 2.5 2.5 1.5 1.5 5.5 7.5 0.5 3.5 0.5]
# 2.9
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
x.std()
# Out:
# 3.5846896657869842

# %%
x.mean()
# Out:
# 34.5

# %%
empty_df = pd.DataFrame({ 'message':[],'type':[]})

# %%
empty_df
# Out:
# Empty DataFrame
# Columns: [message, type]
# Index: []

# %%
#list 

data =  [ 
            ['one',1,2,3],
            ['two',2,3,4],
            ['three',1,2,3]
]

# %%
df = pd.DataFrame(data,columns=['A','B','C','D'],index=['one','two','three'])
df
# Out:
#            A  B  C  D
# one      one  1  2  3
# two      two  2  3  4
# three  three  1  2  3

# %%
from random import randint

# %%
data = [ 

{ 'message':' '.join([ chr(randint(95,122))+chr(randint(95,122))+chr(randint(95,122))+chr(randint(95,122))+chr(randint(95,122)) for var in range(10)]),
  'type': 'positive'}
    
    for var in range(10)

]

# %%
data
# Out:
# [{'message': 'uqxnq mwwsg xaxof vfoou gjnuf mfnoh sxwdr jensc pinrx rc_bp',
#   'type': 'positive'},
#  {'message': 'rziki `kdod agbjg xbeva jyduh cqkie arpbf bsrsr vuiqs dwiqg',
#   'type': 'positive'},
#  {'message': 'wmhug _vrhp wlprn dnevn spiv` `lhjk bgbkz widjo zxi`x clgeu',
#   'type': 'positive'},
#  {'message': 'wjutw _awfh wtzxp xfwyv wp`mk adqto j__jy paajd nteh_ wzdyf',
#   'type': 'positive'},
#  {'message': 'uxhzp hiibo favvp ioijo ixbzn msau` qweb_ ddgrg up`am qfgom',
#   'type': 'positive'},
#  {'message': 'ultua neddf mrfel xcorz _ejdc _znis lqx`h qknak lfccg qybzd',
#   'type': 'positive'},
#  {'message': 'lzenx hxlk` kvkmw esvet kskrt ikmuf szrhv gu`xs ceah_ _fsrw',
#   'type': 'positive'},
#  {'message': 'rstu_ ghtql dfgsr aokbx lbjtx nucpl rzhl` mdlab gu`e` nsxtl',
#   'type': 'positive'},
#  {'message': 'sxbm` qhbwn gywkk itph_ kljxn vfw`b aemom imztl hmdny esjqv',
#   'type': 'positive'},
# ...

# %%
df1  = pd.DataFrame(data)

# %%
df1
# Out:
#                                              message      type
# 0  uqxnq mwwsg xaxof vfoou gjnuf mfnoh sxwdr jens...  positive
# 1  rziki `kdod agbjg xbeva jyduh cqkie arpbf bsrs...  positive
# 2  wmhug _vrhp wlprn dnevn spiv` `lhjk bgbkz widj...  positive
# 3  wjutw _awfh wtzxp xfwyv wp`mk adqto j__jy paaj...  positive
# 4  uxhzp hiibo favvp ioijo ixbzn msau` qweb_ ddgr...  positive
# 5  ultua neddf mrfel xcorz _ejdc _znis lqx`h qkna...  positive
# 6  lzenx hxlk` kvkmw esvet kskrt ikmuf szrhv gu`x...  positive
# 7  rstu_ ghtql dfgsr aokbx lbjtx nucpl rzhl` mdla...  positive
# 8  sxbm` qhbwn gywkk itph_ kljxn vfw`b aemom imzt...  positive
# 9  aloif czoz_ `_myc _iprs mw`ji ukxva qtz_x pxgk...  positive

# %%
data = [ 

{ 'message':' '.join(
[
    ''.join([ chr(randint(65,90)) for var in range(randint(1,10)) ]) 
    
     for var in range(randint(10,50)) ]
  ),
  
 'type': np.random.choice(['negative','postive'])}
    
    for var in range(100)

]

new_df = pd.DataFrame(data)

print(new_df)
# Out:
#                                               message      type
# 0   GXMYNY RPFKNNXJY KDWDFT ZCN HJTSEDTZK UIF JKDE...   postive
# 1   QNCDYQHP JOOMFHOCAR PUMN ILNCQZSX PUCCPU BLA V...  negative
# 2   YDMA BUXWP P HS QWNYDNNQJQ II ON NUUKBT QGAZVR...   postive
# 3   QBRH DMX WLHGGSD KAJPTDXMWW BXOZ NSEHDXS HV RK...   postive
# 4   ULOAM LE MMTZB DWMA MNHRGGD VQOXU V AQYBWRGC I...   postive
# 5   IIMYKT UBVUI RINTX C IZRBBGISDU XVSDCJWBE FATH...   postive
# 6   X OBCGW GDRRFT XHO P CYQYHU NMKAWMYKGE DPKKKAX...   postive
# 7   BESJUYVPC GNQ WEJAAAGMAR CJWITEKWBW ZBEGNMRRFE...  negative
# 8   ENYLRHJWV BNZKIC EBLGKHIC GISNFIGIWC KXSSVLZKG...  negative
# 9   WPERULBVI BFIY XWYFGB MQ JSGOG CJRGCJXP Z CMGN...   postive
# 10  WYASIFDVMR OVSSFARHVL LE DSAOZDFI TXXKXN QO HN...  negative
# 11  NZS RDVLWAJXF QYOKZNKQ ENQNZVT EA MVCQWR EFBS ...  negative
# 12  ZXV FYVXKHRVUS PATTQO JVPGLYKNI FHT AA OKH CUZ...  negative
# 13  FFPMBQOKB BMNI PGTS NJSYKUSUXY OZESRE DNNES WH...  negative
# ...

# %%
df2 = pd.DataFrame(data)

# %%
df2.head()
# Out:
#                                              message      type
# 0  REGVB XBU SWENTHB JUL YH NGFGTMC TXRPFMU APNRR...  negative
# 1  OMKRQA GEAGULB RXUPSFXZO SYEGT D NLHOI GEFNXC ...  negative
# 2  C PXHNDJDHFO TOTGKCRBN EY GRQTEUJPPP UA BEAFNV...  negative
# 3  AGI B TWK K UPKNY UHIO PMPTDIO VRV H F BSIYEAM...  negative
# 4  KEMMWISYJB WPV YQMGN HEOECJXO XLTN ZU LKEQJD H...  negative

# %%
df1.head()
# Out:
#                                              message      type
# 0  uqxnq mwwsg xaxof vfoou gjnuf mfnoh sxwdr jens...  positive
# 1  rziki `kdod agbjg xbeva jyduh cqkie arpbf bsrs...  positive
# 2  wmhug _vrhp wlprn dnevn spiv` `lhjk bgbkz widj...  positive
# 3  wjutw _awfh wtzxp xfwyv wp`mk adqto j__jy paaj...  positive
# 4  uxhzp hiibo favvp ioijo ixbzn msau` qweb_ ddgr...  positive

# %%
empty_df
# Out:
#                                              message      type
# 0  uqxnq mwwsg xaxof vfoou gjnuf mfnoh sxwdr jens...  positive
# 1  rziki `kdod agbjg xbeva jyduh cqkie arpbf bsrs...  positive
# 2  wmhug _vrhp wlprn dnevn spiv` `lhjk bgbkz widj...  positive
# 3  wjutw _awfh wtzxp xfwyv wp`mk adqto j__jy paaj...  positive
# 4  uxhzp hiibo favvp ioijo ixbzn msau` qweb_ ddgr...  positive
# 5  ultua neddf mrfel xcorz _ejdc _znis lqx`h qkna...  positive
# 6  lzenx hxlk` kvkmw esvet kskrt ikmuf szrhv gu`x...  positive
# 7  rstu_ ghtql dfgsr aokbx lbjtx nucpl rzhl` mdla...  positive
# 8  sxbm` qhbwn gywkk itph_ kljxn vfw`b aemom imzt...  positive
# 9  aloif czoz_ `_myc _iprs mw`ji ukxva qtz_x pxgk...  positive
# 0  NRtbp ]Eovi AGjrt YC`ed KPzjr PTp_d KSwpn \Oc`...  negative
# 1  OYns` UHrt_ CGaqe DEhlq ^Bgte COrsn FShvs \Wlj...  negative
# 2  WYmfb VM_ft _^psx JDjoc ^Nhnx HEuhf RDzgd NDwl...  negative
# 3  HOi_c PXylu TVeeo R\yxh _Mjlb VZfdx GZbx_ AAbx...  negative
# ...

# %%
empty_df = empty_df.append(df1)

# %%
empty_df
# Out:
#                                              message      type
# 0  uqxnq mwwsg xaxof vfoou gjnuf mfnoh sxwdr jens...  positive
# 1  rziki `kdod agbjg xbeva jyduh cqkie arpbf bsrs...  positive
# 2  wmhug _vrhp wlprn dnevn spiv` `lhjk bgbkz widj...  positive
# 3  wjutw _awfh wtzxp xfwyv wp`mk adqto j__jy paaj...  positive
# 4  uxhzp hiibo favvp ioijo ixbzn msau` qweb_ ddgr...  positive
# 5  ultua neddf mrfel xcorz _ejdc _znis lqx`h qkna...  positive
# 6  lzenx hxlk` kvkmw esvet kskrt ikmuf szrhv gu`x...  positive
# 7  rstu_ ghtql dfgsr aokbx lbjtx nucpl rzhl` mdla...  positive
# 8  sxbm` qhbwn gywkk itph_ kljxn vfw`b aemom imzt...  positive
# 9  aloif czoz_ `_myc _iprs mw`ji ukxva qtz_x pxgk...  positive
# 0  NRtbp ]Eovi AGjrt YC`ed KPzjr PTp_d KSwpn \Oc`...  negative
# 1  OYns` UHrt_ CGaqe DEhlq ^Bgte COrsn FShvs \Wlj...  negative
# 2  WYmfb VM_ft _^psx JDjoc ^Nhnx HEuhf RDzgd NDwl...  negative
# 3  HOi_c PXylu TVeeo R\yxh _Mjlb VZfdx GZbx_ AAbx...  negative
# ...

# %%
empty_df = empty_df.append(df2)

# %%
empty_df
# Out:
#                                              message      type
# 0  uqxnq mwwsg xaxof vfoou gjnuf mfnoh sxwdr jens...  positive
# 1  rziki `kdod agbjg xbeva jyduh cqkie arpbf bsrs...  positive
# 2  wmhug _vrhp wlprn dnevn spiv` `lhjk bgbkz widj...  positive
# 3  wjutw _awfh wtzxp xfwyv wp`mk adqto j__jy paaj...  positive
# 4  uxhzp hiibo favvp ioijo ixbzn msau` qweb_ ddgr...  positive
# 5  ultua neddf mrfel xcorz _ejdc _znis lqx`h qkna...  positive
# 6  lzenx hxlk` kvkmw esvet kskrt ikmuf szrhv gu`x...  positive
# 7  rstu_ ghtql dfgsr aokbx lbjtx nucpl rzhl` mdla...  positive
# 8  sxbm` qhbwn gywkk itph_ kljxn vfw`b aemom imzt...  positive
# 9  aloif czoz_ `_myc _iprs mw`ji ukxva qtz_x pxgk...  positive
# 0  NRtbp ]Eovi AGjrt YC`ed KPzjr PTp_d KSwpn \Oc`...  negative
# 1  OYns` UHrt_ CGaqe DEhlq ^Bgte COrsn FShvs \Wlj...  negative
# 2  WYmfb VM_ft _^psx JDjoc ^Nhnx HEuhf RDzgd NDwl...  negative
# 3  HOi_c PXylu TVeeo R\yxh _Mjlb VZfdx GZbx_ AAbx...  negative
# ...

# %%
df =  empty_df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                              message      type
# 0  uqxnq mwwsg xaxof vfoou gjnuf mfnoh sxwdr jens...  positive
# 1  rziki `kdod agbjg xbeva jyduh cqkie arpbf bsrs...  positive
# 2  wmhug _vrhp wlprn dnevn spiv` `lhjk bgbkz widj...  positive
# 3  wjutw _awfh wtzxp xfwyv wp`mk adqto j__jy paaj...  positive
# 4  uxhzp hiibo favvp ioijo ixbzn msau` qweb_ ddgr...  positive

# %%
df.tail()
# Out:
#                                               message      type
# 15  \Ma`n O^uzq Z[qnh ONhka FX_hm WDbxt TLhiu ]Aoh...  negative
# 16  LZqnw EBvhh [Abpr ^Dtar LXiws WCzuc \He`n PHhu...  negative
# 17  GCi_b FVtjz JJyvn EWvqd UGlw_ FL_cj Y\lpq BFiw...  negative
# 18  NOq_n IXhxr YQtf_ CBiob KUcxa ]M`gy ]^vhw ZNfs...  negative
# 19  FGycr PWkev EEfj_ RQo`w ^Qzuc ]Zhz` RM`mm TGnj...  negative
